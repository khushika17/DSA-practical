# %%
def evaluate_postfix(expression):
    stack=[]

    for char in expression:
        if char.isdigit():
            stack.append(int(char))
        else:
            b=stack.pop()
            a=stack.pop()

            if char=='+':
                result=a+b
            elif char=='-':
                result=a-b
            elif char=='*':
                result=a*b
            elif char=='/':
                result=a/b
                stack.append(result)
            return stack[0]
        expression=int(input("Enter a expression to evaluate:"))
        result=evaluate_postfix(expression)
        print("Result")
def evaluate_postfix(expression):
    stack = []

    for char in expression:
        if char.isdigit():
            stack.append(int(char))
        else:
            b = stack.pop()
            a = stack.pop()

            if char == '+':
                result = a + b
            elif char == '-':
                result = a - b
            elif char == '*':
                result = a * b
            elif char == '/':
                result = a / b

            stack.append(result)

    return stack[0]


# Example
exp = "23*54*+9-"
print(evaluate_postfix(exp))
# Out:
# 17
